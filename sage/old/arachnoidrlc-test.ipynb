# %%
# %display latex

# %%
var('r f l c');radians = pi/180.0;degrees = 180.0/pi
def argd(x):
    return N(arg(x) * degrees)
def plt(q,a,b,typ = abs,col = 'blue'):
     return plot(lambda x: float(typ(q(x))),(x,a,b),rgbcolor=col)
omega = 2*pi*f    
zs(r,l,c,f) = r + (i*omega*l) - i/(omega*c)

# %%
a = 12;b = 22;r = 1/8;l = 1/100;c = 1/100;
fr=n(1/(2*pi*(sqrt(l*c))))
lbl = text("$f_r = %.0f Hz$" % (fr),(15,3),rgbcolor="red",
           horizontal_alignment="left", fontsize=10,
           vertical_alignment="top",
        bounding_box={'boxstyle':'round', 'fc':'w'}  )
q(f) = zs(r,l,c,f);p1 = plt(1/q,a,b,abs,"red")
zs(r,l,c,f) = r + (i*omega*l) - i/(omega*c)
show(p1+lbl,figsize=(4,3),fontsize=6,frame=True,
     gridlines="minor",gridlinesstyle=dict(color="lightgreen", 
                         linestyle="-",linewidth="0.35"))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
var("omega")
R=0.6;L=1/100;C=1/1000;w=1/(sqrt(L*C));
p=plot(abs(1/(1+i*omega*R*C-omega*omega*L*C)),
       [omega,0,2*w],color="darkgreen")
f=w;r=R;c=C;l=L
lbl = text("$w_r = %.0f rad/s$" % (f),(200,1),
           rgbcolor="darkgreen",
           horizontal_alignment="left",
           fontsize=10,
           bounding_box={'boxstyle':'round', 'fc':'w'})
show(p+lbl,figsize=4,frame=True,axes=False,
     gridlines="minor",fontsize=6,
     gridlinesstyle=dict(color="orange",
                         linestyle="-",
                         linewidth="0.5"))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
yi=4*3.141592653E-7;iy=1/yi;yi,iy
# Out:
# (1.25663706120000e-6, 795774.715608873)

# %%
c=299792458;ya=1/(yi*c*c);ay=1/ya;ya,ay
# Out:
# (8.85418781928265e-12, 1.12940906654612e11)

# %%
qi=1/(yi*ya);qi
# Out:
# 8.98755178736818e16

# %%
round(sqrt(qi))
# Out:
# 299792458

# %%
round(sqrt(iy*ay))
# Out:
# 299792458

# %%
cc=round(ay*iy);cc
# Out:
# 89875517873681760

# %% [markdown]
# ###### An de grâce 2017, mardi 5 décembre 12h06
#
# Une question me vient à l'esprit ?
#
# Est-ce que l'éther n'est pas la lumière ?
#
# z=376.73 $\Omega$ : alors que ça devrait être 360° (1 $\Omega$ égale 1°)
#
# Dans ce cas-la $v=z=c$ et c² = z²

# %%
z=sqrt(yi/ya);zz=yi/ya;z,zz
# Out:
# (376.730313391044, 141925.729027715)

# %%
3.141592653-2.99792458
# Out:
# 0.143668073000000

# %%
2.99-2.71
# Out:
# 0.280000000000000

# %%
3.14/2.99
# Out:
# 1.05016722408027

# %%
2.99/2.71
# Out:
# 1.10332103321033

# %%
1/376.73
# Out:
# 0.00265442093807236

# %%
1/137.035999
# Out:
# 0.00729735257375691

# %%
57.30*2
# Out:
# 114.600000000000

# %%
4*314
# Out:
# 1256

# %%
n(1/pi*360E-8)
# Out:
# 1.14591559026165e-6

# %%
n(0.36/pi)
# Out:
# 0.114591559026165

# %%
1256-1145
# Out:
# 111

# %%
(1.77-1.41)
# Out:
# 0.360000000000000

# %%
c*c
# Out:
# 89875517873681764
