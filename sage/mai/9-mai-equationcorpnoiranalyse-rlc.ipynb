# %%
# %%latex
# $k1=8 \pi h c$ et
# $k2=\frac{hc}{k}$
# Out:
# $k1=8 \pi h c$ et
# $k2=\frac{hc}{k}$

# %%
# %display latex
c=299792458;h=6.626*(10^-34);k = 1.38*(10^-23)

# %%
print"c=",c,"h=",h,"k=",k
# Out:
# c= 299792458 h= 6.62600000000000e-34 k= 1.38000000000000e-23

# %%
c=3e8;h=6.626*(10^-34);k = 1.281*(10^-23)
k1=8*pi*h*c;k2=(h*c)/k
E(l,T)=k1*(l*1e-9)^-5*(1/(exp(k2/((l*1e-9)*T))-1))
f1=0;f2=E(l,3500);f3=E(l,4000);
f4=E(l,4500);f5=E(l,5000)
params=dict(figsize=4,axes=False,
            fontsize=6,
            frame=True,gridlines="major",
            gridlinesstyle=dict(
                color="cyan",
                linestyle="-",alpha=0.3),
            axes_labels=(
                "$\Lambda[nm]$",\
                "$E(\\Lambda)[KJ/nm$"),
            legend_font_size=10)
p0=plot([f1],l,10,4000,fill=f2,
       legend_label="3000",
       fillcolor=["green"],
       fillalpha=1,color="green")
p1=plot([f2],l,10,4000,fill=f3,
       legend_label="3500",
       fillcolor=["violet"],
       fillalpha=1,color="violet")
p2=plot([f3],l,10,4000,fill =f4,
       legend_label="4500",
          fillcolor=['yellow'],
          fillalpha=1,color="yellow")
p3=plot([f4],l,10,4000,fill =f5,
       legend_label="5000",
       fillcolor="red",
       fillalpha=1,color="red")
v=plot(p0+p1+p2+p3)
v.axes_color("brown")
v.axes_label_color("red")
v.tick_label_color("green")
v.show(**params)
# Out:
# Graphics object consisting of 8 graphics primitives

# %%
E(l,T)=k1*(l*1e-9)^-5*(1/(exp(k2/((l*1e-9)*T))-1))

# %%
# %%latex
# $E(\lambda,T)=\frac {8\pi h c}{\lambda^5}
# \frac{1}{e^\frac{hc}{k \lambda T }-1}$
# Out:
# $E(\lambda,T)=\frac {8\pi h c}{\lambda^5}
# \frac{1}{e^\frac{hc}{k \lambda T }-1}$

# %%
n(8 * pi * h * c)
# Out:
# 4.99588630144463e-24

# %%
(h * c) / k
# Out:
# 0.0155175644028103

# %%
# %%latex
# $zs(r,l,c,f) = r + i * omega*L - \frac {i}{omega*C}$
# Out:
# $zs(r,l,c,f) = r + i * omega*L - \frac {i}{omega*C}$

# %% [markdown]
# ![image.png](attachment:image.png)
#
# On voit à travers ce circuit LC, l'univers dans une figure.

# %%
L=10;C=10; n(sqrt(L-1/C))
# Out:
# 3.14642654451045

# %%
n(1/81,digits=34)
# Out:
# 0.01234567901234567901234567901234568

# %%
n(1/81,digits=34)
# Out:
# 0.01234567901234567901234567901234568

# %%
# %%latex
# $f_0=\frac {\omega_0}{2\pi}=\frac{1}{2\pi \sqrt LC}$
# Out:
# $f_0=\frac {\omega_0}{2\pi}=\frac{1}{2\pi \sqrt LC}$

# %%
L=0.1;C=0.01
w=sqrt(1/(L*C));w
# Out:
# 31.6227766016838

# %%
f=1/(2*n(pi)*sqrt(L*C));f
# Out:
# 5.03292121044870

# %% [markdown]
# Je vois que la fréquence correspond au rayon $c=2\pi r = 2 \pi f$,célérité et circonférence !

# %%
Z=i*w*L+(1/i*w*C);Z^2
# Out:
# -8.10000000000000

# %%
Z=(w^2*L*C)*i/w*C;zz=(Z^2);zz
# Out:
# -1.00000000000000e-7

# %%
#reset()

# %%
mu=n(pi*4E-7/(2*pi))/2;mu
# Out:
# 1.00000000000000e-7

# %%
# Out:
# -1.32348898008484e-23
